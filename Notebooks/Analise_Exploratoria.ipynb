# %% [markdown]
# <a href="https://colab.research.google.com/github/JulianoMata/Curso_Alura_Estatistica_Python/blob/main/Notebooks/Analise_Exploratoria.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # <font color=00C0C0>Análise de Vendas</font>

# %%
# Importando as bibliotecas
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use("seaborn")

# %%
# Upload do arquivo
from google.colab import files
arquivo = files.upload()
# Out:
#      <input type="file" id="files-6d80ce1c-7379-424f-ae11-74447490a6df" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6d80ce1c-7379-424f-ae11-74447490a6df">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Criação do Dataframe
df = pd.read_excel("AdventureWorks.xlsx")

# %%
# Visualizando as 5 primeiras linhas
df.head()
# Out:
#   Data Venda Data Envio  ID Loja  ID Produto  ID Cliente       No. Venda  \
# 0 2008-05-09 2008-05-29      199         384       18839  200805093CS607
# 1 2008-05-12 2008-05-17      306         384       19051  200805123CS567
# 2 2008-05-14 2008-05-20      306         384       19052  200805143CS576
# 3 2008-05-21 2008-05-27      306         384       19052  200805213CS576
# 4 2008-06-20 2008-06-27      306         384       19053  200806203CS586
#
#         Custo Unitário       Preço Unitário  Quantidade       Valor Desconto  \
# 0               348.58               758.00           6                 0.00
# 1               348.58               758.00           6                 0.00
# 2               348.58               758.00           6                 0.00
# 3               348.58               758.00           6                 0.00
# 4               348.58               758.00           6                 0.00
#
# ...

# %%
# Quantidade de linhas e colunas
df.shape
# Out:
# (904, 16)

# %%
# Verificando o tipo dos dados
df.dtypes
# Out:
# Data Venda        datetime64[ns]
# Data Envio        datetime64[ns]
# ID Loja                    int64
# ID Produto                 int64
# ID Cliente                 int64
# No. Venda                 object
# Custo Unitário           float64
# Preço Unitário           float64
# Quantidade                 int64
# Valor Desconto           float64
# Valor Venda              float64
# Produto                   object
# Fabricante                object
# Marca                     object
# Classe                    object
# Cor                       object
# dtype: object

# %%
# Qual a 'Receita total'?
print(f' O Valor da Receita é \033[4;32mR$ {df["Valor Venda"].sum().round(2)}\033[m')
# Out:
#  O Valor da Receita é R$ 5984606.14

# %%
# Criando a coluna 'Custo'
df["Custo"] = df["Custo Unitário"].mul(df["Quantidade"])
df.head()
# Out:
#   Data Venda Data Envio  ID Loja  ID Produto  ID Cliente       No. Venda  \
# 0 2008-05-09 2008-05-29      199         384       18839  200805093CS607
# 1 2008-05-12 2008-05-17      306         384       19051  200805123CS567
# 2 2008-05-14 2008-05-20      306         384       19052  200805143CS576
# 3 2008-05-21 2008-05-27      306         384       19052  200805213CS576
# 4 2008-06-20 2008-06-27      306         384       19053  200806203CS586
#
#         Custo Unitário       Preço Unitário  Quantidade       Valor Desconto  \
# 0               348.58               758.00           6                 0.00
# 1               348.58               758.00           6                 0.00
# 2               348.58               758.00           6                 0.00
# 3               348.58               758.00           6                 0.00
# 4               348.58               758.00           6                 0.00
#
# ...

# %%
# Qual o 'Custo total'?
print(f'O custo total é \033[4;32mR$ {df["Custo"].sum():,.2f}\033[m')
# Out:
# O custo total é R$ 2,486,783.05

# %%
# Agora temos 'Receita', 'Custo Total'. Podemos achar 'Lucro Total'!
# Criar uma coluna 'Lucro' que será ('Receita' - 'Custo')
df["Lucro"] = df["Valor Venda"] - df["Custo"]
df.head()
# Out:
#   Data Venda Data Envio  ID Loja  ID Produto  ID Cliente       No. Venda  \
# 0 2008-05-09 2008-05-29      199         384       18839  200805093CS607
# 1 2008-05-12 2008-05-17      306         384       19051  200805123CS567
# 2 2008-05-14 2008-05-20      306         384       19052  200805143CS576
# 3 2008-05-21 2008-05-27      306         384       19052  200805213CS576
# 4 2008-06-20 2008-06-27      306         384       19053  200806203CS586
#
#         Custo Unitário       Preço Unitário  Quantidade       Valor Desconto  \
# 0               348.58               758.00           6                 0.00
# 1               348.58               758.00           6                 0.00
# 2               348.58               758.00           6                 0.00
# 3               348.58               758.00           6                 0.00
# 4               348.58               758.00           6                 0.00
#
# ...

# %%
# Total Lucro?
print(f'O lucro total é \033[4;32mR$ {df["Lucro"].sum():,.2f}\033[m')
# Out:
# O lucro total é R$ 3,497,823.09

# %%
# Criando uma coluna com total de dias para enviar o produto
df["Tempo_envio"] = df["Data Envio"] - df["Data Venda"]
df.head()
# Out:
#   Data Venda Data Envio  ID Loja  ID Produto  ID Cliente       No. Venda  \
# 0 2008-05-09 2008-05-29      199         384       18839  200805093CS607
# 1 2008-05-12 2008-05-17      306         384       19051  200805123CS567
# 2 2008-05-14 2008-05-20      306         384       19052  200805143CS576
# 3 2008-05-21 2008-05-27      306         384       19052  200805213CS576
# 4 2008-06-20 2008-06-27      306         384       19053  200806203CS586
#
#         Custo Unitário       Preço Unitário  Quantidade       Valor Desconto  \
# 0               348.58               758.00           6                 0.00
# 1               348.58               758.00           6                 0.00
# 2               348.58               758.00           6                 0.00
# 3               348.58               758.00           6                 0.00
# 4               348.58               758.00           6                 0.00
#
# ...

# %% [markdown]
# #### <font color=00C0C0>Precisamos converter a coluna 'Tempo_envio' para numérica. Queremos saber a média do tempo de envio para cada 'Marca'</font>

# %%
# Extraindo apenas os dias
df["Tempo_envio"] = (df["Data Envio"] - df["Data Venda"]).dt.days
df.head()
# Out:
#   Data Venda Data Envio  ID Loja  ID Produto  ID Cliente       No. Venda  \
# 0 2008-05-09 2008-05-29      199         384       18839  200805093CS607
# 1 2008-05-12 2008-05-17      306         384       19051  200805123CS567
# 2 2008-05-14 2008-05-20      306         384       19052  200805143CS576
# 3 2008-05-21 2008-05-27      306         384       19052  200805213CS576
# 4 2008-06-20 2008-06-27      306         384       19053  200806203CS586
#
#         Custo Unitário       Preço Unitário  Quantidade       Valor Desconto  \
# 0               348.58               758.00           6                 0.00
# 1               348.58               758.00           6                 0.00
# 2               348.58               758.00           6                 0.00
# 3               348.58               758.00           6                 0.00
# 4               348.58               758.00           6                 0.00
#
# ...

# %%
# Verificando o tipo da coluna 'Tempo_envio'
df["Tempo_envio"].dtype
# Out:
# dtype('int64')

# %%
# Média do tempo de envio por 'Marca'
media_tempo_envio_marca = df.groupby("Marca")["Tempo_envio"].mean().round(2).reset_index()
media_tempo_envio_marca
# Out:
#              Marca          Tempo_envio
# 0  Adventure Works                 8.66
# 1          Contoso                 8.47
# 2         Fabrikam                 8.51

# %% [markdown]
# #### <font color=00C0C0>Missing Values</font>

# %%
# Verificando existência de dados faltantes
df.isnull().sum()
# Out:
# Data Venda        0
# Data Envio        0
# ID Loja           0
# ID Produto        0
# ID Cliente        0
# No. Venda         0
# Custo Unitário    0
# Preço Unitário    0
# Quantidade        0
# Valor Desconto    0
# Valor Venda       0
# Produto           0
# Fabricante        0
# Marca             0
# Classe            0
# Cor               0
# Custo             0
# Lucro             0
# Tempo_envio       0
# dtype: int64

# %% [markdown]
# <font color=00C0C0>Lucro por 'Ano' e 'Marca'</font>

# %%
pd.options.display.float_format = '{:20,.2f}'.format

# %%
# Vamos Agrupar por 'Ano' e 'Marca'
# Resetando 'index'
lucro_por_ano_marca = df.groupby([df["Data Venda"].dt.year, "Marca"])["Lucro"].sum().reset_index()
lucro_por_ano_marca
# Out:
#    Data Venda            Marca                Lucro
# 0        2008  Adventure Works           306,641.16
# 1        2008          Contoso            56,416.00
# 2        2008         Fabrikam         1,557,020.55
# 3        2009  Adventure Works           405,395.08
# 4        2009          Contoso           138,258.95
# 5        2009         Fabrikam         1,034,091.35

# %%
# Qual uantidade dos produtos vendidos por produto?
# Ao resetar o indice o gráfico não aparece nome do produto e sim os números.
total_produtos_vendidos = pd.DataFrame(df.groupby("Produto")["Quantidade"].sum().sort_values(ascending = False)).reset_index()
total_produtos_vendidos
# Out:
#                                            Produto  Quantidade
# 0  Headphone Adapter for Contoso Phone E130 Silver       25232
# 1   Headphone Adapter for Contoso Phone E130 White       25008
# 2          Adventure Works Laptop15.4W M1548 Black        1089
# 3        Fabrikam Trendsetter 2/3'' 17mm X100 Grey        1087
# 4            Adventure Works Laptop15.4W M1548 Red        1047
# 5       Fabrikam Trendsetter 2/3'' 17mm X100 Black         926
# 6      Fabrikam Trendsetter 1/3'' 8.5mm X200 Black         884
# 7       Fabrikam Trendsetter 1/3'' 8.5mm X200 Grey         845
# 8      Fabrikam Trendsetter 1/3'' 8.5mm X200 White         789

# %%
df.groupby("Produto")["Quantidade"].sum().sort_values(ascending = True).plot.barh(title = "Total Produtos Vendidos", figsize=(10, 6), color = "#80C040");

# %%
# Total lucro por ano
total_lucro_ano = df.groupby(df["Data Venda"].dt.year)["Lucro"].sum().reset_index()
total_lucro_ano
# Out:
#    Data Venda                Lucro
# 0        2008         1,920,077.71
# 1        2009         1,577,745.38

# %%
df.groupby(df["Data Venda"].dt.year)["Lucro"].sum().plot.bar(title = "Lucro x Ano", figsize=(10, 6), color = "#C040C0")
plt.xlabel("Ano")
plt.ylabel("Receita")
plt.xticks(rotation = "horizontal");

# %%
# Selecionando apenas as vendas de 2009
df_2009 = df[df["Data Venda"].dt.year == 2009]
df_2009.head()
# Out:
#    Data Venda Data Envio  ID Loja  ID Produto  ID Cliente       No. Venda  \
# 11 2009-05-02 2009-05-14      199         384       18938  200905023CS847
# 12 2009-05-16 2009-05-27      306         384       19067  200905163CS746
# 13 2009-05-31 2009-06-12      306         384       19068  200905313CS748
# 14 2009-06-28 2009-07-11      199         384       18959  200906283CS870
# 15 2009-07-08 2009-07-12      306         384       19070  200907083CS757
#
#          Custo Unitário       Preço Unitário  Quantidade       Valor Desconto  \
# 11               348.58               758.00           6                 0.00
# 12               348.58               758.00           6                 0.00
# 13               348.58               758.00           6                 0.00
# 14               348.58               758.00           6                 0.00
# 15               348.58               758.00           6                 0.00
#
# ...

# %%
df_2009.groupby(df_2009["Data Venda"].dt.month)["Lucro"].sum().plot(title = "Lucro x Mês", figsize=(10, 6), color = "#C040C0")
plt.xlabel("Mês")
plt.ylabel("Lucro");

# %%
df_2009.groupby(df_2009["Marca"])["Lucro"].sum().plot.bar(title = "Lucro x Marca", figsize=(10, 6), color = "#0000FF")
plt.xlabel("Marca")
plt.ylabel("Lucro")
plt.xticks(rotation = "horizontal");

# %%
df_2009.groupby(df_2009["Classe"])["Lucro"].sum().plot.bar(title = "Lucro x Classe", figsize=(10, 6), color = "#FF4080")
plt.xlabel("Mês")
plt.ylabel("Lucro")
plt.xticks(rotation = "horizontal");

# %%
# Dados estatisticos
df.describe().round(2)
# Out:
#                    ID Loja           ID Produto           ID Cliente  \
# count               904.00               904.00               904.00
# mean                270.02             1,225.24            19,029.09
# std                  50.96               706.70                96.43
# min                 199.00               366.00            18,815.00
# 25%                 199.00               384.00            18,964.75
# 50%                 306.00             1,202.00            19,060.00
# 75%                 307.00             1,226.00            19,107.00
# max                 307.00             2,497.00            19,145.00
#
#             Custo Unitário       Preço Unitário           Quantidade  \
# count               904.00               904.00               904.00
# mean                272.01               742.53                62.95
# std                 129.77               368.59               148.95
# ...

# %%
df["Tempo_envio"].describe()
# Out:
# count                 904.00
# mean                    8.54
# std                     3.06
# min                     4.00
# 25%                     6.00
# 50%                     9.00
# 75%                    11.00
# max                    20.00
# Name: Tempo_envio, dtype: float64

# %%
# Gráfico de Boxplot
plt.figure(figsize=(10, 6))
plt.boxplot(df["Tempo_envio"]);

# %%
# Histograma
plt.figure(figsize=(10, 6))
plt.hist(df["Tempo_envio"], bins=15, edgecolor="yellow", color="green");

# %%
# Tempo mínimo de envio
df["Tempo_envio"].min()
# Out:
# 4

# %%
# Tempo máximo de envio
df["Tempo_envio"].max()
# Out:
# 20

# %%
# Identificando o 'Outlier'
df[df["Tempo_envio"] == 20]
# Out:
#   Data Venda Data Envio  ID Loja  ID Produto  ID Cliente       No. Venda  \
# 0 2008-05-09 2008-05-29      199         384       18839  200805093CS607
#
#         Custo Unitário       Preço Unitário  Quantidade       Valor Desconto  \
# 0               348.58               758.00           6                 0.00
#
#            Valor Venda                                Produto  \
# 0             4,548.00  Adventure Works Laptop15.4W M1548 Red
#
#         Fabricante            Marca   Classe  Cor                Custo  \
# 0  Adventure Works  Adventure Works  Regular  Red             2,091.48
#
#                  Lucro  Tempo_envio
# 0             2,456.52           20

# %%
df.to_csv("df_vendas_novo.csv", index = False)
